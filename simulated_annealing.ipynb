# %% [markdown]
# # Solving the SApHLP problem using simulated annealing
#
# This notebook inclludes the implementation of the Simulated Annealing (SA) algorithm for a hub location problem. The SA algorithm is a probabilistic technique for approximating the global optimum of a given function. Here, we specifically use it to find an optimal set of hubs in a transportation network.
#
# The algorithm is based on principles from statistical mechanics and the process of annealing in metallurgy. It uses a metaphor of heating a material and then slowly cooling it to decrease defects and increase the size of the constituent crystals to find an optimal solution.
#
# I perform a sensitivity analysis on different parameters such as the temperature, cooling rate (alpha), and number of iterations. The datasets used include different sizes of transportation networks (ranging from 10 to 100 nodes) with corresponding flow and cost matrices.

# %%
# load the data
# %run data_preparation.ipynb

# %%
# import libraries
import time
import csv
import numpy as np

# load the functions
from hub_operations import neighbour, neighbour3, initial_solution, total_cost

# %%
# # Define the constants
RESULTS_FILE = 'SA_results.csv'
FM_NAMES = ['CAB_25_fm', 'TR_55_fm', 'TR_81_fm', 'RGP_100_fm']
NUMBER_OF_HUBS_DICT = {'CAB_10_fm': [3], 'CAB_25_fm': [3,5], 'TR_55_fm': [3,5], 'TR_81_fm': [5,7], 'RGP_100_fm': [7,10]}
TEMPERATURES = [1_000_000_000, 10_000_000_000, 100_000_000_000]
ALPHAS = [0.96, 0.97, 0.98, 0.99]
MAX_TS_DICT = {'CAB_10_fm': [500], 'CAB_25_fm': [2000], 'TR_55_fm': [2500], 'TR_81_fm': [5000], 'RGP_100_fm': [6000]}

# # Write headers to results file
# with open(RESULTS_FILE, 'a') as f:
#     writer = csv.writer(f)
#     writer.writerow(['SA Algorithm', 'fm_name', 'cm_name', 'number_of_hubs', 'max_iter', 'T', 'temp', 'alpha', 'best_cost[-1]', 'best_solution[-1]', 'best_cost',  'best_solution', 'total_time'])

# %%
# Store the matrices in a dictionary
matrices = {
    'CAB_10_fm': CAB_10_fm,
    'CAB_10_cm': CAB_10_cm,
    'CAB_25_fm': CAB_25_fm,
    'CAB_25_cm': CAB_25_cm,
    'TR_55_fm': TR_55_fm,
    'TR_55_cm': TR_55_cm,
    'TR_81_fm': TR_81_fm,
    'TR_81_cm': TR_81_cm,
    'RGP_100_fm': RGP_100_fm,
    'RGP_100_cm': RGP_100_cm
}

results_file = 'SA_results.csv'

with open(results_file, 'a') as f:
    writer = csv.writer(f)
    writer.writerow(['SA Algorithm', 'fm_name', 'cm_name', 'number_of_hubs', 'max_iter', 'T', 'temp', 'alpha', 'best_cost[-1]', 'best_solution[-1]', 'best_cost',  'best_solution', 'total_time'])

# Rest of the code goes here

# %%
# Simulated annealing algorithm
def simulated_annealing(T, alpha, max_iter, fm, fm_name, cm, cm_name, number_of_hubs):
    """Simulated annealing algorithm for hub location problem.

    Args:
    T: Initial temperature for annealing process.
    alpha: Cooling rate.
    max_iter: Maximum number of iterations.
    fm: Flow matrix.
    fm_name: Name of the flow matrix.
    cm: Cost matrix.
    cm_name: Name of the cost matrix.
    number_of_hubs: Number of hubs in the problem.

    Returns:
    best_solution: Best solution found.
    best_cost: Cost of the best solution.
    current_cost: Cost of the current solution.
    """
    # Initialize solution
    initial_sol = initial_solution(fm, cm, number_of_hubs)

    # Start timer
    start_time = time.time()

    # Set initial solution and cost
    current_solution = [initial_sol]
    current_cost = [total_cost(fm , cm, current_solution[-1])]

    # Set initial best solution and cost
    best_solution = [current_solution[-1]]
    best_cost = [current_cost[-1]]

    # Initialize temperature
    temp = [T]

    # Counter for accepted worse solutions
    counter = 0

    # Iteratively generate and evaluate solutions
    for i in range(max_iter):
        # Generate neighbour solution
        new_solution = neighbour(current_solution[-1]) if np.random.random() <= 0.5 else neighbour3(current_solution[-1])

        # Calculate cost of new solution
        new_cost = total_cost(fm, cm, new_solution)

        # If new solution is better, accept it and decrease temperature
        if new_cost < current_cost[-1]:
            current_solution.append(new_solution)
            current_cost.append(new_cost)
            temp.append(alpha * temp[-1])

            # If new solution is the best so far, update best solution and cost
            if new_cost < best_cost[-1]:
                best_solution.append(new_solution)
                best_cost.append(new_cost)
        else:
            # If new solution is worse, accept it with certain probability
            p = np.exp(-(new_cost - current_cost[-1]) / temp[-1])
            if np.random.random() <= p:
                current_solution.append(new_solution)
                current_cost.append(new_cost)
                temp.append(alpha * temp[-1])
                counter += 1

            # Append current best solution and cost
            best_solution.append(best_solution[-1])
            best_cost.append(best_cost[-1])

    # Stop timer and calculate total time
    total_time = time.time() - start_time
    print(f'Timer ended. Total time: {total_time}')
    print(f'Worse solution accepted: {counter} times')
    print(f'Best cost: {best_cost[-1]}')

    # Write results to file
    with open(RESULTS_FILE, 'a') as f:
        writer = csv.writer(f)
        writer.writerow(['SA Algorithm', fm_name, cm_name, number_of_hubs, max_iter, T, temp, alpha, best_cost[-1], best_solution[-1], best_cost, best_solution, total_time])

    return best_solution, best_cost, current_cost

# %%
def run_simulated_annealing(iterations, fm_names, number_of_hubs_dict, temperatures, alphas, max_ts_dict):
    """Run the simulated annealing algorithm with various parameters for a certain number of iterations.

    Args:
    iterations: Number of iterations to run the algorithm.
    fm_names: List of flow matrix names.
    number_of_hubs_dict: Dictionary with number of hubs for each flow matrix.
    temperatures: List of initial temperatures for the annealing process.
    alphas: List of cooling rates.
    max_ts_dict: Dictionary with maximum number of iterations for each flow matrix.
    """
    for i in range(iterations):
        print('---------------------------------------------------------------------------------')
        print(f'Iteration: {i}')
        for fm_name in fm_names:
            cm_name = fm_name.replace('fm', 'cm')
            for number_of_hubs in number_of_hubs_dict[fm_name]:
                for max_t in max_ts_dict[fm_name]:
                    for T in temperatures:
                        for alpha in alphas:
                            print(f'fm_name: {fm_name}, cm_name: {cm_name}, number_of_hubs: {number_of_hubs}, max_t: {max_t}, T: {T}, alpha: {alpha}')
                            # Run simulated annealing
                            simulated_annealing(T, alpha, max_t, matrices[fm_name], fm_name, matrices[cm_name], cm_name, number_of_hubs)
                            print('Run completed.')

# %%
# Run the algorithm for 10 iterations with different parameters
run_simulated_annealing(10, FM_NAMES, NUMBER_OF_HUBS_DICT, TEMPERATURES, ALPHAS, MAX_TS_DICT)
# Out:
# ---------------------------------------------------------------------------------
# Iteration: 0
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 1000000000, alpha: 0.96
# Timer ended. Total time:
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 9.06688666343689
# Worse solution accepted: 80 times
# Best cost: 135074087134.77277
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 8.852871179580688
# Worse solution accepted: 99 times
# Best cost: 135304231618.39656
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 9.056271314620972
# Worse solution accepted: 179 times
# Best cost: 134739043175.2495
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 8.747280836105347
# Worse solution accepted: 401 times
# Best cost: 136261448968.15697
# Run completed.
# ---------------------------------------------------------------------------------
# Iteration: 2
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 0.31117963790893555
# Worse solution accepted: 42 times
# Best cost: 9756972299.965881
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 0.26797938346862793
# Worse solution accepted: 69 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 0.27945566177368164
# Worse solution accepted: 89 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 0.3431861400604248
# Worse solution accepted: 142 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 0.4893946647644043
# Worse solution accepted: 71 times
# Best cost: 8478428502.4042
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3283669948577881
# Worse solution accepted: 113 times
# Best cost: 8478428502.4042
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 0.3011345863342285
# Worse solution accepted: 155 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 0.27517151832580566
# Worse solution accepted: 268 times
# Best cost: 8404033493.755039
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 0.2778356075286865
# Worse solution accepted: 99 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 0.36342954635620117
# Worse solution accepted: 138 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 0.2910165786743164
# Worse solution accepted: 199 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 0.2855501174926758
# Worse solution accepted: 362 times
# Best cost: 8526861774.7686
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 0.8049170970916748
# Worse solution accepted: 51 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 0.6769692897796631
# Worse solution accepted: 65 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 0.6420366764068604
# Worse solution accepted: 101 times
# Best cost: 7658571002.3972
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 0.7322075366973877
# Worse solution accepted: 163 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 0.6618177890777588
# Worse solution accepted: 83 times
# Best cost: 7858848563.916279
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.7162559032440186
# Worse solution accepted: 101 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 0.6204934120178223
# Worse solution accepted: 145 times
# Best cost: 8192766487.56696
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 1.036104440689087
# Worse solution accepted: 271 times
# Best cost: 7741075515.054081
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 0.688612699508667
# Worse solution accepted: 95 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 0.6513502597808838
# Worse solution accepted: 126 times
# Best cost: 7925032061.867482
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 0.9542152881622314
# Worse solution accepted: 210 times
# Best cost: 8235264488.88844
# Run completed.
# ...
# Best cost: 8365400693.011558
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 0.38683366775512695
# Worse solution accepted: 44 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 0.36886072158813477
# Worse solution accepted: 61 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 0.383512020111084
# Worse solution accepted: 88 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 0.37227392196655273
# Worse solution accepted: 158 times
# Best cost: 28157709789.8
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 0.3804962635040283
# Worse solution accepted: 68 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.44167041778564453
# Worse solution accepted: 95 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 0.3980281352996826
# Worse solution accepted: 149 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 0.3930063247680664
# Worse solution accepted: 256 times
# Best cost: 28207193580.2
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 0.3685131072998047
# Worse solution accepted: 108 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 0.38032078742980957
# Worse solution accepted: 140 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 0.3779275417327881
# Worse solution accepted: 204 times
# Best cost: 30168987242.6
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 0.4211881160736084
# Worse solution accepted: 379 times
# Best cost: 28507259772.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 0.8776359558105469
# Worse solution accepted: 35 times
# Best cost: 25006624075.59999
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 0.8629586696624756
# Worse solution accepted: 53 times
# Best cost: 24715031884.2
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 1.0025322437286377
# Worse solution accepted: 82 times
# Best cost: 26065681720.199997
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 1.2228572368621826
# Worse solution accepted: 160 times
# Best cost: 25262326706.800007
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 0.822678804397583
# Worse solution accepted: 60 times
# Best cost: 26834445042.800007
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.8793389797210693
# Worse solution accepted: 91 times
# Best cost: 24896884491.800003
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 0.8440191745758057
# Worse solution accepted: 130 times
# Best cost: 25304919182.999992
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 0.914165735244751
# Worse solution accepted: 265 times
# Best cost: 25053149662.199993
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 0.822441816329956
# Worse solution accepted: 88 times
# Best cost: 24446490493.800003
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 0.8017616271972656
# Worse solution accepted: 127 times
# Best cost: 24841266361.800003
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 0.8492865562438965
# Worse solution accepted: 191 times
# Best cost: 24163244370.599995
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 0.855804443359375
# Worse solution accepted: 367 times
# Best cost: 24993131581.8
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 2.1966607570648193
# Worse solution accepted: 31 times
# Best cost: 44601658394.03202
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 1.8552329540252686
# Worse solution accepted: 48 times
# Best cost: 44334919083.62424
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 2.0102427005767822
# Worse solution accepted: 81 times
# Best cost: 45287019969.81905
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 2.0500240325927734
# Worse solution accepted: 160 times
# Best cost: 45382208606.85311
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 1.9802627563476562
# Worse solution accepted: 53 times
# Best cost: 44601658394.03202
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 2.2583041191101074
# Worse solution accepted: 79 times
# Best cost: 46844461746.07496
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 2.285022497177124
# Worse solution accepted: 133 times
# Best cost: 46340555552.422066
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 2.1069469451904297
# Worse solution accepted: 269 times
# Best cost: 44539012728.878685
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 1.9727401733398438
# Worse solution accepted: 78 times
# Best cost: 43925561481.83122
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 2.0152761936187744
# Worse solution accepted: 130 times
# Best cost: 46712679124.62656
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 2.18329119682312
# Worse solution accepted: 184 times
# Best cost: 44305358010.03594
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 1.9184222221374512
# Worse solution accepted: 365 times
# Best cost: 45349931521.76055
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 3.278301954269409
# Worse solution accepted: 29 times
# Best cost: 41185394077.87813
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 3.223778486251831
# Worse solution accepted: 42 times
# Best cost: 40915948029.351524
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 3.4674041271209717
# Worse solution accepted: 74 times
# Best cost: 41476617564.15398
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 3.706270933151245
# Worse solution accepted: 142 times
# Best cost: 40822655741.79386
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 3.2961251735687256
# Worse solution accepted: 48 times
# Best cost: 39905650214.887314
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 3.2818431854248047
# Worse solution accepted: 79 times
# Best cost: 41806171965.96653
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 3.40364146232605
# Worse solution accepted: 123 times
# Best cost: 41569767237.80973
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 3.449894905090332
# Worse solution accepted: 250 times
# Best cost: 41942786431.875305
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 3.8007240295410156
# Worse solution accepted: 83 times
# Best cost: 41304453672.222305
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 3.404170036315918
# Worse solution accepted: 109 times
# Best cost: 41590234621.97784
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 3.572786331176758
# Worse solution accepted: 187 times
# Best cost: 41747109494.43651
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 3.1787283420562744
# Worse solution accepted: 393 times
# Best cost: 41197459155.59771
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 4.979027271270752
# Worse solution accepted: 28 times
# Best cost: 137191566655.14395
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 5.151660680770874
# Worse solution accepted: 39 times
# Best cost: 135804373263.17943
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 4.945234298706055
# Worse solution accepted: 70 times
# Best cost: 135249962434.04341
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 5.308099746704102
# Worse solution accepted: 154 times
# Best cost: 135395634741.39531
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 5.0394017696380615
# Worse solution accepted: 65 times
# Best cost: 137542153589.4223
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 5.161548614501953
# Worse solution accepted: 83 times
# Best cost: 136146038213.95306
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 4.880290985107422
# Worse solution accepted: 129 times
# Best cost: 136511376473.58316
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 5.185500860214233
# Worse solution accepted: 257 times
# Best cost: 135764054576.51604
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 4.922408103942871
# Worse solution accepted: 88 times
# Best cost: 135065239288.12823
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 5.146158695220947
# Worse solution accepted: 114 times
# Best cost: 138060048436.24377
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 5.2980945110321045
# Worse solution accepted: 186 times
# Best cost: 136163070811.46274
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 5.12186598777771
# Worse solution accepted: 397 times
# Best cost: 136739117006.96739
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 1000000000, alpha: 0.96
# Timer ended. Total time: 9.138352632522583
# Worse solution accepted: 27 times
# Best cost: 134849727152.76953
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 1000000000, alpha: 0.97
# Timer ended. Total time: 9.326829671859741
# Worse solution accepted: 44 times
# Best cost: 134850395605.57272
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 1000000000, alpha: 0.98
# Timer ended. Total time: 9.178500890731812
# Worse solution accepted: 63 times
# Best cost: 135532952736.09729
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 1000000000, alpha: 0.99
# Timer ended. Total time: 9.118491411209106
# Worse solution accepted: 149 times
# Best cost: 134819957303.69273
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.96
# Timer ended. Total time: 9.464586734771729
# Worse solution accepted: 58 times
# Best cost: 133588136562.8743
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 10.125596284866333
# Worse solution accepted: 83 times
# Best cost: 135202258514.56343
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.98
# Timer ended. Total time: 9.993755102157593
# Worse solution accepted: 129 times
# Best cost: 135475032291.99493
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.99
# Timer ended. Total time: 9.746748685836792
# Worse solution accepted: 281 times
# Best cost: 134594908336.99759
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.96
# Timer ended. Total time: 9.47398829460144
# Worse solution accepted: 81 times
# Best cost: 134234150175.16405
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.97
# Timer ended. Total time: 9.18267560005188
# Worse solution accepted: 115 times
# Best cost: 134650167939.66187
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.98
# Timer ended. Total time: 8.774271488189697
# Worse solution accepted: 188 times
# Best cost: 133303404370.04002
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 100000000000, alpha: 0.99
# Timer ended. Total time: 8.681142091751099
# Worse solution accepted: 377 times
# Best cost: 135362722577.55669
# Run completed.

# %%
# Final run with specific parameters
FINAL_TEMPERATURES = [10_000_000_000]
FINAL_ALPHAS = [0.97]
run_simulated_annealing(10, FM_NAMES, NUMBER_OF_HUBS_DICT, FINAL_TEMPERATURES, FINAL_ALPHAS, MAX_TS_DICT)
# Out:
# ---------------------------------------------------------------------------------
# Iteration: 0
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.2990090847015381
# Worse solution accepted: 95 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.6638531684875488
# Worse solution accepted: 90 times
# Best cost: 8017861264.586398
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3661768436431885
# Worse solution accepted: 95 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.8787834644317627
# Worse solution accepted: 82 times
# Best cost: 25674801251.999996
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 1.8762538433074951
# Worse solution accepted: 83 times
# Best cost: 43957317042.69502
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 3.0243561267852783
# Worse solution accepted: 77 times
# Best cost: 41174176476.04795
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 4.780587434768677
# Worse solution accepted: 80 times
# Best cost: 135452622311.7069
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 9.74905514717102
# Worse solution accepted: 77 times
# Best cost: 134396601742.24684
# Run completed.
# ---------------------------------------------------------------------------------
# Iteration: 1
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.27101993560791016
# Worse solution accepted: 108 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.6748616695404053
# Worse solution accepted: 98 times
# Best cost: 8258241996.926359
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3627305030822754
# Worse solution accepted: 101 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.8468828201293945
# Worse solution accepted: 88 times
# Best cost: 25103797432.59999
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 1.7466869354248047
# Worse solution accepted: 90 times
# Best cost: 47089699139.66105
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 3.2156476974487305
# Worse solution accepted: 82 times
# Best cost: 40832239461.727684
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 4.985759735107422
# Worse solution accepted: 72 times
# Best cost: 135601205195.94716
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 8.781038522720337
# Worse solution accepted: 94 times
# Best cost: 135597673808.39565
# Run completed.
# ---------------------------------------------------------------------------------
# Iteration: 2
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3221292495727539
# Worse solution accepted: 104 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.6061751842498779
# Worse solution accepted: 100 times
# Best cost: 8287020482.84504
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3772711753845215
# Worse solution accepted: 97 times
# Best cost: 28150828563.8
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.8250782489776611
# Worse solution accepted: 89 times
# Best cost: 25250000984.000008
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 1.8150792121887207
# Worse solution accepted: 82 times
# Best cost: 43925561481.83122
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 3.1684274673461914
# Worse solution accepted: 68 times
# Best cost: 40355553979.67703
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 5.008997917175293
# Worse solution accepted: 87 times
# Best cost: 137122013482.31146
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 8.788215398788452
# Worse solution accepted: 80 times
# Best cost: 135024034657.96686
# Run completed.
# ---------------------------------------------------------------------------------
# Iteration: 3
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 3, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.2847888469696045
# Worse solution accepted: 99 times
# Best cost: 8374475034.11352
# Run completed.
# fm_name: CAB_25_fm, cm_name: CAB_25_cm, number_of_hubs: 5, max_t: 2000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.6264739036560059
# Worse solution accepted: 95 times
# Best cost: 7822886029.460759
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 3, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.3740506172180176
# Worse solution accepted: 98 times
# Best cost: 28147615297.0
# Run completed.
# fm_name: TR_55_fm, cm_name: TR_55_cm, number_of_hubs: 5, max_t: 2500, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 0.8465683460235596
# Worse solution accepted: 80 times
# Best cost: 24878208784.599995
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 5, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 1.7685272693634033
# Worse solution accepted: 72 times
# Best cost: 47284931050.76193
# Run completed.
# fm_name: TR_81_fm, cm_name: TR_81_cm, number_of_hubs: 7, max_t: 5000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 3.1380348205566406
# Worse solution accepted: 76 times
# Best cost: 40757534448.08118
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 7, max_t: 6000, T: 10000000000, alpha: 0.97
# Timer ended. Total time: 4.495995998382568
# Worse solution accepted: 80 times
# Best cost: 137063009377.51094
# Run completed.
# fm_name: RGP_100_fm, cm_name: RGP_100_cm, number_of_hubs: 10, max_t: 6000, T: 10000000000, alpha: 0.97
